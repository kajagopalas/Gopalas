# %%
import pandas as PD
import numpy as NP

# %%
import pandas as pd

# Function to convert sentiment
def converter_Sentiment_cell(cell):
    if cell == "Positive":
        return '+Ve'
    elif cell == "Negative":
        return '-Ve'
    elif cell == "Neutral":
        return '+-'  # Neutral sentiment
    return cell  # Return the cell if it's not one of the defined values

# Define the data
Consumer_Sentiments_and_Ratings = {
    'ProductID' : ['A123','B456','C789','A123','D012','E345','B456','F678','C789','G901','A123','H234','D012','I567','E345','B456','J890','F678','K123','G901','A123','L456','C789','D012','E345','B456','M789','F678','N012','G901'],
    'ReviewText' : ['Loved the product! Great features and easy to use.',
                    'It was okay, nothing special. Expected more for the price.',
                    'Terrible! Broke within a week. Avoid at all costs.',
                    'Excellent! Battery life is amazing.',
                    'Decent product, does what it\'s supposed to.',
                    'Absolutely fantastic! Best purchase I\'ve made in a long time.',
                    'Disappointed. The quality is subpar.',
                    'Good value for money, but could be better.',
                    'Amazing! Super fast delivery and the product is perfect.',
                    'Mediocre. It\'s functional, but not impressive.',
                    'The screen is too dim. Not satisfied.',
                    'Very happy with my purchase. Highly recommend.',
                    'It\'s alright. Does the job.',
                    'Incredible! The sound quality is outstanding.',
                    'Waste of money. Stopped working after a month.',
                    'Pretty good, but the software is buggy.',
                    'Perfect for my needs. Simple and effective.',
                    'Average. Nothing to write home about.',
                    'Exceptional! Exceeded my expectations.',
                    'Poorly designed. Difficult to use.',
                    ' "I am very pleased with the speed of this product."',
                    ' "The instructions were very hard to follow."',
                    ' "This product is exactly as advertised',
                    ' "It does the job',
                    ' "This product is a game changer! I love it!"',
                    ' "The color was not what I expected."',
                    ' "Easy to use and reliable. Great purchase."',
                    ' "It\'s fine',
                    ' "Absolutely love this product! Would buy again."',
                    ' "The size was smaller than I thought."'],
    'Sentiment': ['Positive','Neutral','Negative','Positive','Neutral','Positive','Negative','Neutral','Positive','Neutral','Negative','Positive','Neutral','Positive','Negative','Neutral','Positive','Neutral','Positive','Negative','Positive','Negative',' Positive',' Neutral','Positive','Negative','Positive',' Neutral','Positive','Negative'],
    'Rating': ['5','3','1','4','3','5','2','4','5','3','2','4','3','5','1','3','4','3','5','2','4','2','5','3','5','2','4','3','5','2'],
    'Purchase': ['10/26/2023','10/27/2023','10/28/2023','10/29/2023','10/30/2023','11/1/2023','11/2/2023','11/3/2023','11/4/2023','11/5/2023','11/6/2023','11/7/2023','11/8/2023','11/9/2023','11/10/2023','11/11/2023','11/12/2023','11/13/2023','11/14/2023','11/15/2023','11/16/2023','11/17/2023','11/18/2023','11/19/2023','11/20/2023','11/21/2023','11/22/2023','11/23/2023','11/24/2023','11/25/2023'],
    'Location': ['New York','London','Tokyo','Paris','Sydney','Toronto','Berlin','Mumbai','Chicago','Dubai','Los Angeles','Singapore','Rio de Janeiro','Moscow','Johannesburg','Mexico City','Seoul','Madrid','Rome','Amsterdam','Vancouver','Buenos Aires','Stockholm','Dublin','Copenhagen','Brussels','Vienna','Athens','Prague','Budapest'],
    'Device': ['Mobile','Tablet','Laptop','Mobile','Desktop','Mobile','Tablet','Laptop','Mobile','Desktop','Mobile','Tablet','Laptop','Mobile','Desktop','Mobile','Tablet','Laptop','Mobile','Desktop','Mobile','Tablet','Laptop','Mobile','Desktop','Mobile','Tablet','Laptop','Mobile','Desktop']
}

# Create the DataFrame
DFCSR = pd.DataFrame(Consumer_Sentiments_and_Ratings)

# Strip any leading or trailing spaces from the 'Sentiment' column and apply the converter function
DFCSR['Sentiment'] = DFCSR['Sentiment'].str.strip().apply(converter_Sentiment_cell)

# %%
import pandas as pd
import numpy as np

# Function to convert the payment method
def converter_PaymentMethod_cell(cell):
    if cell == "Credit Card":
        return 'CC'
    elif cell == "PayPal":
        return 'PP'
    elif cell == "Debit Card":
        return 'DC'
    return cell  # Default return if no match

# Define the data dictionary
E_Commerce_Data_Sales = {
    'CustomerID': ['CUST123', 'CUST456', 'CUST789', 'CUST123', 'CUST234', 'CUST567', 'CUST789', 'CUST890', 'CUST345', 'CUST678', 'CUST901', 'CUST123', 'CUST456', 'CUST789', 'CUST234', 'CUST567', 'CUST890', 'CUST345', 'CUST678', 'CUST901', 'CUST123', 'CUST456', 'CUST789', 'CUST234', 'CUST567', 'CUST890', 'CUST345', 'CUST678', 'CUST901'],
    'ProductID': ['PROD456', 'PROD789', 'PROD101', 'PROD456', 'PROD202', 'PROD303', 'PROD789', 'PROD404', 'PROD505', 'PROD606', 'PROD707', 'PROD808', 'PROD909', 'PROD101', 'PROD202', 'PROD303', 'PROD404', 'PROD505', 'PROD606', 'PROD707', 'PROD808', 'PROD909', 'PROD101', 'PROD202', 'PROD303', 'PROD404', 'PROD505', 'PROD606', 'PROD707'],
    'ProductName': ['Laptop', 'T-Shirt', 'Headphones', 'Laptop', 'Jeans', 'Mouse', 'T-Shirt', 'Keyboard', 'Dress', 'Monitor', 'Shoes', 'Printer', 'Socks', 'Headphones', 'Jeans', 'Mouse', 'Keyboard', 'Dress', 'Monitor', 'Shoes', 'Printer', 'Socks', 'Headphones', 'Jeans', 'Mouse', 'Keyboard', 'Dress', 'Monitor', 'Shoes'],
    'Category': ['Electronics', 'Clothing', 'Electronics', 'Electronics', 'Clothing', 'Electronics', 'Clothing', 'Electronics', 'Clothing', 'Electronics', 'Clothing', 'Electronics', 'Clothing', 'Electronics', 'Clothing', 'Electronics', 'Electronics', 'Clothing', 'Electronics', 'Clothing', 'Electronics', 'Clothing', 'Electronics', 'Clothing', 'Electronics', 'Electronics', 'Clothing', 'Electronics', 'Clothing'],
    'Quantity': [1, 3, 1, 1, 2, 1, 2, 1, 1, 1, 1, 1, 5, 1, 2, 1, 1, 1, 1, 1, 1, 5, 1, 2, 1, 1, 1, 1, 1],
    'UnitPrice': [1200, 25, 150, 1200, 60, 30, 25, 80, 80, 300, 70, 200, 10, 150, 60, 30, 80, 80, 300, 70, 200, 10, 150, 60, 30, 80, 80, 300, 70],
    'PurchaseDate': ['10/26/2023 10:00', '10/27/2023 14:30', '10/28/2023 11:15', '10/29/2023 9:45', '10/30/2023 16:20', '11/1/2023', '11/2/2023 13:00', '11/3/2023 10:30', '11/4/2023 15:45', '11/5/2023 12:00', '11/6/2023 17:10', '11/7/2023 9:30', '11/8/2023 14:00', '11/9/2023 11:00', '11/10/2023 16:00', '11/11/2023', '11/12/2023 10:00', '11/13/2023 15:00', '11/14/2023 12:30', '11/15/2023 17:30', '11/16/2023 9:00', '11/17/2023 13:30', '11/18/2023 11:30', '11/19/2023 16:30', '11/20/2023', '11/21/2023 10:30', '11/22/2023 15:30', '11/23/2023 12:00', '11/24/2023 17:00'],
    'ShippingAddress': ['123 Main St Anytown', '456 Oak Ave Somecity', np.nan, '123 Main St Anytown', '789 Pine Ln Othertown', '101 Elm Rd Newcity', '456 Oak Ave Somecity', '202 Maple Dr Oldtown', '303 Birch St Anyville', '404 Willow Ct Someville', '505 Cedar Ave Otherville', '123 Main St Anytown', '456 Oak Ave Somecity', '456 Oak Ave Somecity', '789 Pine Ln Othertown', '101 Elm Rd Newcity', '202 Maple Dr Oldtown', np.nan, '404 Willow Ct Someville', '505 Cedar Ave Otherville', '123 Main St Anytown', '456 Oak Ave Somecity', '456 Oak Ave Somecity', '789 Pine Ln Othertown', '101 Elm Rd Newcity', '202 Maple Dr Oldtown', '303 Birch St Anyville', np.nan, np.nan],
    'PaymentMethod': ['Credit Card', 'PayPal', 'Debit Card', 'Credit Card', 'PayPal', 'Credit Card', np.nan, 'Debit Card', 'PayPal', 'Credit Card', 'PayPal', 'Debit Card', np.nan, 'Credit Card', 'PayPal', 'Credit Card', 'Debit Card', 'PayPal', 'Credit Card', 'PayPal', 'Debit Card', 'Credit Card', 'PayPal', 'Credit Card', 'Debit Card', 'PayPal', 'Credit Card', 'Debit Card', np.nan],
    'ReviewRating': ['4.5', '3', '5', '4', '2.5', '4.8', '3.5', '4.2', '1', '4.7', '3.8', '4.3', '2', '5', '2.8', '4.9', '4', '1.5', '4.6', '3.9', '4.4', '2.2', '5', '2.7', '4.8', '4.1', '1.2', '4.7', np.nan],
    'CustomerFeedback': ['Great laptop but slow delivery.', 'Color was different than expected.', 'Excellent sound quality.', 'Good laptop minor scratches.', 'Size was incorrect.', 'Smooth and responsive.', 'Decent quality for the price.', 'Comfortable to type on.', 'Terrible fit and poor material.', 'Great display quality.', 'Comfortable shoes but laces broke.', 'Easy to set up and use.', 'Thin and low quality.', 'Amazing headphones fast delivery.', 'Wrong size again.', 'Very precise mouse.', 'Space bar sticks sometimes.', 'Stitching came undone after one wash.', 'Clear and bright monitor.', 'Good for everyday wear.', 'Prints quickly and clearly.', 'Holes appeared after first wash.', 'Best headphones I\'ve ever owned.', 'Very uncomfortable.', 'Excellent value for money.', 'Some keys are a bit sticky.', 'Completely see-through.', 'Perfect for gaming.', np.nan]
}

# Create the DataFrame
dfEComDS = pd.DataFrame(E_Commerce_Data_Sales)

# Apply the converter function to the 'PaymentMethod' column
dfEComDS['PaymentMethod'] = dfEComDS['PaymentMethod'].apply(converter_PaymentMethod_cell)

# Print the updated DataFrame
print(dfEComDS)
# Out:
#    CustomerID ProductID ProductName     Category  Quantity  UnitPrice  \
# 0     CUST123   PROD456      Laptop  Electronics         1       1200
# 1     CUST456   PROD789     T-Shirt     Clothing         3         25
# 2     CUST789   PROD101  Headphones  Electronics         1        150
# 3     CUST123   PROD456      Laptop  Electronics         1       1200
# 4     CUST234   PROD202       Jeans     Clothing         2         60
# 5     CUST567   PROD303       Mouse  Electronics         1         30
# 6     CUST789   PROD789     T-Shirt     Clothing         2         25
# 7     CUST890   PROD404    Keyboard  Electronics         1         80
# 8     CUST345   PROD505       Dress     Clothing         1         80
# 9     CUST678   PROD606     Monitor  Electronics         1        300
# 10    CUST901   PROD707       Shoes     Clothing         1         70
# 11    CUST123   PROD808     Printer  Electronics         1        200
# ...

# %%
import pandas as pd

# Ensure that DFECDS is already defined as a DataFrame
# For example, assume DFECDS is already defined:
# DFECDS = pd.DataFrame(E_Commerce_Data_Sales)

# Save both DataFrames to an Excel file
file_path = "C:\\Users\\Admin\\OneDrive\\Desktop\\CSR_ECDS.xlsx"

with pd.ExcelWriter(file_path) as CSR_ECDS:
    DFCSR.to_excel(CSR_ECDS, sheet_name="CSR", index=False)
    DFECDS.to_excel(CSR_ECDS, sheet_name="ECDS", index=False)

# %%
DF=PD.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\CSR_ECDS.xlsx",sheet_name="ECDS")
