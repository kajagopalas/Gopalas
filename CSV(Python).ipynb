# %%
import pandas as PD

DF=PD.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\Employee.csv")

# %%
DF
# Out:
#     Employee_ID First_Name  Last_Name  Age   Department  Salary
# 0             1       John        Doe   29           HR   55000
# 1             2       Jane      Smith   34    Marketing   62000
# 2             3        Sam    Johnson   28  Engineering   75000
# 3             4      Emily      Davis   45      Finance   95000
# 4             5    Michael      Brown   38           IT   78000
# ..          ...        ...        ...  ...          ...     ...
# 95           96        Eli    Stanley   29           IT   78000
# 96           97        Zoe     Watson   41        Sales   52000
# 97           98      Sofia     Curtis   34    Marketing   64000
# 98           99     Sophie    Russell   38  Engineering   71000
# 99          100      David  Henderson   30           HR   58000
#
# [100 rows x 6 columns]

# %%
DF
# Out:
#     Employee_ID First_Name  Last_Name  Age   Department  Salary
# 0             1       John        Doe   29           HR   55000
# 1             2       Jane      Smith   34    Marketing   62000
# 2             3        Sam    Johnson   28  Engineering   75000
# 3             4      Emily      Davis   45      Finance   95000
# 4             5    Michael      Brown   38           IT   78000
# ..          ...        ...        ...  ...          ...     ...
# 95           96        Eli    Stanley   29           IT   78000
# 96           97        Zoe     Watson   41        Sales   52000
# 97           98      Sofia     Curtis   34    Marketing   64000
# 98           99     Sophie    Russell   38  Engineering   71000
# 99          100      David  Henderson   30           HR   58000
#
# [100 rows x 6 columns]

# %%
DF[:]
# Out:
#     Employee_ID First_Name  Last_Name  Age   Department  Salary
# 0             1       John        Doe   29           HR   55000
# 1             2       Jane      Smith   34    Marketing   62000
# 2             3        Sam    Johnson   28  Engineering   75000
# 3             4      Emily      Davis   45      Finance   95000
# 4             5    Michael      Brown   38           IT   78000
# ..          ...        ...        ...  ...          ...     ...
# 95           96        Eli    Stanley   29           IT   78000
# 96           97        Zoe     Watson   41        Sales   52000
# 97           98      Sofia     Curtis   34    Marketing   64000
# 98           99     Sophie    Russell   38  Engineering   71000
# 99          100      David  Henderson   30           HR   58000
#
# [100 rows x 6 columns]

# %%
DF.shape
# Out:
# (100, 6)

# %%
DF.head()
# Out:
#    Employee_ID First_Name Last_Name  Age   Department  Salary
# 0            1       John       Doe   29           HR   55000
# 1            2       Jane     Smith   34    Marketing   62000
# 2            3        Sam   Johnson   28  Engineering   75000
# 3            4      Emily     Davis   45      Finance   95000
# 4            5    Michael     Brown   38           IT   78000

# %%
DF.tail()
# Out:
#     Employee_ID First_Name  Last_Name  Age   Department  Salary
# 95           96        Eli    Stanley   29           IT   78000
# 96           97        Zoe     Watson   41        Sales   52000
# 97           98      Sofia     Curtis   34    Marketing   64000
# 98           99     Sophie    Russell   38  Engineering   71000
# 99          100      David  Henderson   30           HR   58000

# %%
DF[1:98]
# Out:
#     Employee_ID First_Name Last_Name  Age   Department  Salary
# 1             2       Jane     Smith   34    Marketing   62000
# 2             3        Sam   Johnson   28  Engineering   75000
# 3             4      Emily     Davis   45      Finance   95000
# 4             5    Michael     Brown   38           IT   78000
# 5             6      Sarah  Williams   22        Sales   48000
# ..          ...        ...       ...  ...          ...     ...
# 93           94    Matthew     Bauer   39  Engineering   74000
# 94           95      Grace   Griffin   32           HR   57000
# 95           96        Eli   Stanley   29           IT   78000
# 96           97        Zoe    Watson   41        Sales   52000
# 97           98      Sofia    Curtis   34    Marketing   64000
#
# [97 rows x 6 columns]

# %%
DF.head(55)
# Out:
#     Employee_ID First_Name   Last_Name  Age   Department  Salary
# 0             1       John         Doe   29           HR   55000
# 1             2       Jane       Smith   34    Marketing   62000
# 2             3        Sam     Johnson   28  Engineering   75000
# 3             4      Emily       Davis   45      Finance   95000
# 4             5    Michael       Brown   38           IT   78000
# 5             6      Sarah    Williams   22        Sales   48000
# 6             7      David       Jones   50    Marketing   89000
# 7             8      Laura      Garcia   27  Engineering   70000
# 8             9      James    Martinez   41           HR   58000
# 9            10   Patricia    Anderson   33           IT   76000
# 10           11      Chris      Taylor   31           HR   64000
# 11           12    Jessica      Miller   26    Marketing   57000
# 12           13       Mark      Wilson   29  Engineering   72000
# ...

# %%
DF.tail(33)
# Out:
#     Employee_ID First_Name  Last_Name  Age   Department  Salary
# 67           68  Sebastian        Lee   29  Engineering   71000
# 68           69       Jack      Clark   36           HR   58000
# 69           70   Scarlett     Morris   40           IT   78000
# 70           71      David     Wilson   27    Marketing   60000
# 71           72   Samantha      Evans   32  Engineering   75000
# 72           73     Sophia      Green   34           HR   57000
# 73           74      Aiden    Edwards   33           IT   74000
# 74           75     Nathan    Collins   30    Marketing   63000
# 75           76       Jack    Stewart   41  Engineering   76000
# 76           77       Lily    Simmons   29        Sales   52000
# 77           78      Emily      Davis   40           HR   55000
# 78           79        Eli     Wright   28           IT   77000
# 79           80     George      Baker   35    Marketing   62000
# 80           81    Lillian    Stanley   31  Engineering   73000
# ...

# %%
DF.Salary.sum()
# Out:
# 6699000

# %%
DF.Salary.mean()
# Out:
# 66990.0

# %%
DF.Salary.max()
# Out:
# 100000

# %%
DF.Salary.min()
# Out:
# 48000

# %%
DF.Salary.count()
# Out:
# 100

# %%
DF[DF.Salary>= 70000]
# Out:
#     Employee_ID First_Name   Last_Name  Age   Department  Salary
# 2             3        Sam     Johnson   28  Engineering   75000
# 3             4      Emily       Davis   45      Finance   95000
# 4             5    Michael       Brown   38           IT   78000
# 6             7      David       Jones   50    Marketing   89000
# 7             8      Laura      Garcia   27  Engineering   70000
# 9            10   Patricia    Anderson   33           IT   76000
# 12           13       Mark      Wilson   29  Engineering   72000
# 13           14      Linda       Moore   42      Finance  100000
# 14           15       Paul     Jackson   35           IT   80000
# 17           18      Megan      Martin   24  Engineering   75000
# 19           20       Rita     Roberts   28           IT   74000
# 20           21      Steve       Lopez   45      Finance   90000
# 22           23      Peter       Lewis   38  Engineering   73000
# ...

# %%
DF[DF.Salary>= DF.Salary.min()]
# Out:
#     Employee_ID First_Name  Last_Name  Age   Department  Salary
# 0             1       John        Doe   29           HR   55000
# 1             2       Jane      Smith   34    Marketing   62000
# 2             3        Sam    Johnson   28  Engineering   75000
# 3             4      Emily      Davis   45      Finance   95000
# 4             5    Michael      Brown   38           IT   78000
# ..          ...        ...        ...  ...          ...     ...
# 95           96        Eli    Stanley   29           IT   78000
# 96           97        Zoe     Watson   41        Sales   52000
# 97           98      Sofia     Curtis   34    Marketing   64000
# 98           99     Sophie    Russell   38  Engineering   71000
# 99          100      David  Henderson   30           HR   58000
#
# [100 rows x 6 columns]

# %%
DF.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
DF.set_index('Employee_ID',inplace=True)

# %%
DF
# Out:
#             First_Name  Last_Name  Age   Department  Salary
# Employee_ID
# 1                 John        Doe   29           HR   55000
# 2                 Jane      Smith   34    Marketing   62000
# 3                  Sam    Johnson   28  Engineering   75000
# 4                Emily      Davis   45      Finance   95000
# 5              Michael      Brown   38           IT   78000
# ...                ...        ...  ...          ...     ...
# 96                 Eli    Stanley   29           IT   78000
# 97                 Zoe     Watson   41        Sales   52000
# 98               Sofia     Curtis   34    Marketing   64000
# 99              Sophie    Russell   38  Engineering   71000
# 100              David  Henderson   30           HR   58000
#
# [100 rows x 5 columns]

# %%
Df
